# %%
import pandas as pd
import numpy as np

# %%
import os

# Get the current directory
current_directory = os.getcwd()

# Get the parent directory
parent_directory = os.path.dirname(current_directory)

# Now you can use 'parent_directory' to reference the parent directory.
print("Current Directory:", current_directory)
print("Parent Directory:", parent_directory)
# Out:
# Current Directory: /Users/shiveshkodali/Desktop/GitProjects/TamuDatathon22/data/text
# Parent Directory: /Users/shiveshkodali/Desktop/GitProjects/TamuDatathon22/data

# %%
training_data = pd.read_csv(parent_directory+'/training_split.csv')
val_data = pd.read_csv(parent_directory+'/validation_split.csv')
test_data = pd.read_csv(parent_directory+'/test.csv')

# %%
training_data.approved.value_counts()
# Out:
# False    3282
# True     2307
# Name: approved, dtype: int64

# %%
val_data.approved.value_counts()
# Out:
# False    605
# True     382
# Name: approved, dtype: int64

# %%
training_data.head()
# Out:
#                                      id  user_edited  \
# 0  3cd960de-c4dc-4533-86d7-0497824065e7        False
# 1  d647b590-9f5c-49f8-a8e4-5bb283ae4b9b        False
# 2  c5a74f17-b255-44de-9556-8418d56c423c        False
# 3  d0e89121-2263-4e9e-bd9d-aec1ea120af6        False
# 4  5e5666b5-f246-420d-b3e1-2f87d095c9d4        False
#
#                                                 font  \
# 0  https://marky-fonts.s3.us-east-2.amazonaws.com...
# 1                                                NaN
# 2  https://marky-fonts.s3.us-east-2.amazonaws.com...
# 3  https://marky-fonts.s3.us-east-2.amazonaws.com...
# 4                                                NaN
#
#                                                image  \
# 0  https://marky-image-posts.s3.amazonaws.com/27d...
# 1  https://marky-image-posts.s3.amazonaws.com/334...
# 2  https://marky-image-posts.s3.amazonaws.com/3f4...
# 3  https://marky-image-posts.s3.amazonaws.com/760...
# ...

# %%
# from sklearn.model_selection import train_test_split

# %%
# train, val = train_test_split(training_data, test_size=0.15, random_state=42)

# %%
# train.to_csv("training_split.csv",index=False)
# val.to_csv("validation_split.csv",index=False)

# %%
training_data.parameters_tone.value_counts()
# Out:
# informational    1833
# promotional      1793
# inspirational    1772
# Name: parameters_tone, dtype: int64

# %%
training_data.parameters_switchboard_template_name.value_counts()
# Out:
# blue-template-57      139
# blue-template-58      135
# surprised-man-meme    123
# blue-template-60      120
# blue-template-61      107
#                      ...
# marky-template-16       1
# active-template-9       1
# marky-template-15       1
# marky-template-4        1
# marky-template-7        1
# Name: parameters_switchboard_template_name, Length: 265, dtype: int64

# %%
training_data.parameters_theme.value_counts()
# Out:
# meme             1065
# blue              796
# ugc               656
# bee               533
# teal              406
# coffee            319
# black & white     300
# bold tech         278
# Karate            237
# fresh             234
# minimalism        155
# beauty            124
# Mega               89
# cyber              74
# classic            41
# Marky              14
# john deere         10
# membership          5
# Active              3
# joyful              1
# UGC                 1
# mega                1
# Name: parameters_theme, dtype: int64

# %%
training_data.parameters_prompt_template_name.value_counts()
# Out:
# cta-belief                     230
# three-contents                 183
# did-you-know-2-cta             131
# surprised-man-meme-prompt      123
# cta-arent-you-tired            116
#                               ...
# john-deere-maintenance-tips      1
# john-deere-hotncold              1
# john-deere-trivia                1
# john-deere-trivia-content        1
# john-deere-weather-content       1
# Name: parameters_prompt_template_name, Length: 124, dtype: int64

# %%
training_data.parameters_photo_search_term.value_counts()
# Out:
# images                                     15
# self-improvement                           10
# strategies                                 10
# UW College Republicans                     10
# University of Washington                    7
#                                            ..
# inclusive learning environment              1
# community building for content creators     1
# written content technology                  1
# opulent homes                               1
# AI in competitive world                     1
# Name: parameters_photo_search_term, Length: 3109, dtype: int64

# %%
prompt_user_edited = {
    1 : 'user edited post',
    0 : 'user did not edit post'
}
def prompt_caption(text):
    if text=='':
        return ''
    return 'caption is ' + text

def prompt_parameters_tone(text):
    if text=='':
        return ''
    return 'tone is ' + text

def prompt_parameters_chapter_title(text):
    if text=='':
        return ''
    return 'chapter title is ' + text
def promt_parameters_chapter_summary(text):
    if text=='':
        return ''
    return 'summary is ' + text

def promt_parameters_theme(text):
    if text=='':
        return ''
    return 'theme is ' + text

def prompt_parameters_photo_search_term(text):
    if text=='':
        return ''
    else:
        return 'search term used is ' + text

def prompt_has_logo(text):
    if text:
        return 'it has a logo'
    else:
        return 'it does not have a logo'

# %%
import string


def remove_punctuation(text):
    return ''.join(char for char in text if char not in string.punctuation)

import re

def remove_special_characters_and_numbers(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text

import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

def remove_stopwords(text):
    words = text.split()
    stop_words = set(stopwords.words('english')) 
    filtered_words = [word for word in words if word.lower() not in stop_words]
    cleaned_text = ' '.join(filtered_words)
    return cleaned_text

contraction_mapping = {
    "ain't": "is not",
    "aren't": "are not",
    "can't": "cannot",
    "could've": "could have",
    "couldn't": "could not",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'll": "he will",
    "he's": "he is",
    "I'd": "I would",
    "I'll": "I will",
    "I'm": "I am",
    "I've": "I have",
    "isn't": "is not",
    "it'd": "it would",
    "it'll": "it will",
    "it's": "it is",
    "let's": "let us",
    "mightn't": "might not",
    "mustn't": "must not",
    "shan't": "shall not",
    "she'd": "she would",
    "she'll": "she will",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "that's": "that is",
    "there's": "there is",
    "they'd": "they would",
    "they'll": "they will",
    "they're": "they are",
    "they've": "they have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'll": "we will",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "where's": "where is",
    "who'd": "who would",
    "who'll": "who will",
    "who're": "who are",
    "who's": "who is",
    "who've": "who have",
    "won't": "will not",
    "wouldn't": "would not",
    "you'd": "you would",
    "you'll": "you will",
    "you're": "you are",
    "you've": "you have"
    # Add more contractions and their expansions as needed
}

def expand_contractions(text):
    # Split the text into words
    words = text.split()
    
    # Iterate through the words and replace contractions with their expansions
    expanded_words = [contraction_mapping.get(word, word) for word in words]
    
    # Reconstruct the text with expanded contractions
    expanded_text = ' '.join(expanded_words)
    
    return expanded_text

import re

def remove_urls(text):
    # Define a regular expression pattern to match URLs
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    
    # Use the pattern to replace URLs with an empty string
    cleaned_text = url_pattern.sub('', text)
    
    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shiveshkodali/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_text(text):
    text = text.lower()
    text = expand_contractions(text)
    text = remove_urls(text)
    text = remove_punctuation(text)
    text = remove_special_characters_and_numbers(text)
    text = remove_stopwords(text)
    return text

# %%
clean_columns = ['caption','parameters_chapter_title','parameters_chapter_summary','parameters_tone', 'parameters_theme', 'parameters_photo_search_term']

# %%
for col in clean_columns:
    training_data[col] = training_data[col].apply(lambda text : clean_text(str(text)))

# %%
prompt_text = []
for i in range(len(training_data)):
    text = ''
    sample = training_data.iloc[i,:]
    text += prompt_user_edited[sample['user_edited']]
    text += ' '
    text += prompt_caption(sample['caption'])
    text += ' '
    text += prompt_parameters_chapter_title(sample['parameters_chapter_title'])
    text += ' '
    text += promt_parameters_chapter_summary(sample['parameters_chapter_summary'])
    text += ' '
    text += prompt_parameters_photo_search_term(sample['parameters_photo_search_term'])
    text += ' '
    text += prompt_parameters_tone(sample['parameters_tone'])
    text += ' '
    text += promt_parameters_theme(sample['parameters_theme'])
    text += ' '
    text += prompt_has_logo(sample['has_logo'])
    prompt_text.append(text)

# %%
prompt_text[0]
# Out:
# 'user did not edit post caption is break free chains selfdoubt unleash true potential embrace mindset shift conquer limiting beliefs propelling productivity extraordinary levels dare dream big success awaits refuse settle anything less chapter title is art productivity summary is master art productivity learn accomplish less time discover effective time management techniques productivity hacks revolutionize workweek search term used is productivity hacks tone is inspirational theme is mega it has a logo'

# %%
prompt_text = [clean_text(t) for t in prompt_text]

# %%
training_data['prompt_text'] = prompt_text

# %%
for col in clean_columns:
    val_data[col] = val_data[col].apply(lambda text : clean_text(str(text)))

# %%
prompt_text = []
for i in range(len(val_data)):
    text = ''
    sample = val_data.iloc[i,:]
    text += prompt_user_edited[sample['user_edited']]
    text += ' '
    text += prompt_caption(sample['caption'])
    text += ' '
    text += prompt_parameters_chapter_title(sample['parameters_chapter_title'])
    text += ' '
    text += promt_parameters_chapter_summary(sample['parameters_chapter_summary'])
    text += ' '
    text += prompt_parameters_photo_search_term(sample['parameters_photo_search_term'])
    text += ' '
    text += prompt_parameters_tone(sample['parameters_tone'])
    text += ' '
    text += promt_parameters_theme(sample['parameters_theme'])
    text += ' '
    text += prompt_has_logo(sample['has_logo'])
    prompt_text.append(text)

# %%
prompt_text = [clean_text(t) for t in prompt_text]

# %%
val_data['prompt_text'] = prompt_text

# %%
for col in clean_columns:
    test_data[col] = test_data[col].apply(lambda text : clean_text(str(text)))

# %%
prompt_text = []
for i in range(len(test_data)):
    text = ''
    sample = test_data.iloc[i,:]
    text += prompt_user_edited[sample['user_edited']]
    text += ' '
    text += prompt_caption(sample['caption'])
    text += ' '
    text += prompt_parameters_chapter_title(sample['parameters_chapter_title'])
    text += ' '
    text += promt_parameters_chapter_summary(sample['parameters_chapter_summary'])
    text += ' '
    text += prompt_parameters_photo_search_term(sample['parameters_photo_search_term'])
    text += ' '
    text += prompt_parameters_tone(sample['parameters_tone'])
    text += ' '
    text += promt_parameters_theme(sample['parameters_theme'])
    text += ' '
    text += prompt_has_logo(sample['has_logo'])
    prompt_text.append(text)

# %%
prompt_text = [clean_text(t) for t in prompt_text]

# %%
test_data['prompt_text'] = prompt_text

# %%
training_data.to_csv("train_data_text_ver1.csv",index=False)
val_data.to_csv("val_data_text_ver1.csv",index=False)
test_data.to_csv("test_data_text_ver1.csv",index=False)

# %%
# !pip install wordcloud matplotlib

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine the list of text into a single string
train_text_combined = ' '.join(training_data['caption'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(train_text_combined)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine the list of text into a single string
train_text_combined = ' '.join(training_data['parameters_chapter_summary'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(train_text_combined)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine the list of text into a single string
train_text_combined = ' '.join(training_data['parameters_chapter_title'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(train_text_combined)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine the list of text into a single string
train_text_combined = ' '.join([i for i in training_data['parameters_photo_search_term'] if i!='nan'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(train_text_combined)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
